# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
marvel = pd.read_csv('characters_stats.csv')

# %%
marvel.head()
# Out:
#    Unnamed: 0  ID           Name Alignment_x  Gender EyeColor  \
# 0           0   0         A-Bomb        good    Male   yellow
# 1           1   3    Abomination         bad    Male    green
# 2           2   4        Abraxas         bad    Male     blue
# 3           3   5  Absorbing Man         bad    Male     blue
# 4           4   8       Agent 13        good  Female     blue
#
#                 Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 0              Human   No Hair  Marvel Comics         -  ...         False
# 1  Human / Radiation   No Hair  Marvel Comics         -  ...         False
# 2      Cosmic Entity     Black  Marvel Comics         -  ...         False
# 3              Human   No Hair  Marvel Comics         -  ...         False
# 4                  -     Blond  Marvel Comics         -  ...           NaN
#
#    Reality Warping  Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# ...

# %%
marvel.shape
# Out:
# (382, 186)

# %%
marvel['Alignment_x'].value_counts()
# Out:
# Alignment_x
# good       254
# bad        114
# neutral     11
# -            3
# Name: count, dtype: int64

# %%
marvel[marvel['Alignment_x']=='good']
# Out:
#      Unnamed: 0   ID             Name Alignment_x  Gender EyeColor  \
# 0             0    0           A-Bomb        good    Male   yellow
# 4             4    8         Agent 13        good  Female     blue
# 5             5    9        Agent Bob        good    Male    brown
# 6             6   10       Agent Zero        good    Male        -
# 10           10   22            Angel        good    Male     blue
# ..          ...  ...              ...         ...     ...      ...
# 376         376  725             X-23        good  Female    green
# 377         377  726            X-Man        good    Male     blue
# 379         379  728     Yellowjacket        good    Male     blue
# 380         380  729  Yellowjacket II        good  Female     blue
# 381         381  730             Ymir        good    Male    white
#
#                Race         HairColor      Publisher SkinColor  ...  \
# 0             Human           No Hair  Marvel Comics         -  ...
# ...

# %%
good = marvel[marvel['Alignment_x']=='good']

# %%
good.head()
# Out:
#     Unnamed: 0  ID        Name Alignment_x  Gender EyeColor   Race HairColor  \
# 0            0   0      A-Bomb        good    Male   yellow  Human   No Hair
# 4            4   8    Agent 13        good  Female     blue      -     Blond
# 5            5   9   Agent Bob        good    Male    brown  Human     Brown
# 6            6  10  Agent Zero        good    Male        -      -         -
# 10          10  22       Angel        good    Male     blue      -     Blond
#
#         Publisher SkinColor  ...  Web Creation  Reality Warping  Odin Force  \
# 0   Marvel Comics         -  ...         False            False       False
# 4   Marvel Comics         -  ...           NaN              NaN         NaN
# 5   Marvel Comics         -  ...         False            False       False
# 6   Marvel Comics         -  ...         False            False       False
# 10  Marvel Comics         -  ...         False            False       False
#
# ...

# %%
good.sort_values(by=['Speed'],ascending=False).head()
# Out:
#      Unnamed: 0   ID            Name Alignment_x  Gender      EyeColor  \
# 183         183  349  Jack of Hearts        good    Male  blue / white
# 43           43   95      Black Bolt        good    Male          blue
# 321         321  633        Stardust        good    Male             -
# 252         252  497         Nova II        good  Female         white
# 270         270  538     Quicksilver        good    Male          blue
#
#                Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 183           Human     Brown  Marvel Comics         -  ...         False
# 43          Inhuman     Black  Marvel Comics         -  ...         False
# 321               -         -  Marvel Comics         -  ...         False
# 252  Human / Cosmic       Red  Marvel Comics      gold  ...         False
# 270          Mutant    Silver  Marvel Comics         -  ...         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# ...

# %%
good.sort_values(by=['Power'],ascending=False).head()
# Out:
#      Unnamed: 0   ID        Name Alignment_x  Gender EyeColor            Race  \
# 252         252  497     Nova II        good  Female    white  Human / Cosmic
# 177         177  338      Iceman        good    Male    brown          Mutant
# 43           43   95  Black Bolt        good    Male     blue         Inhuman
# 260         260  518     Phoenix        good  Female    green          Mutant
# 35           35   79    Beyonder        good    Male        -   God / Eternal
#
#     HairColor      Publisher SkinColor  ...  Web Creation  Reality Warping  \
# 252       Red  Marvel Comics      gold  ...         False            False
# 177     Brown  Marvel Comics         -  ...         False            False
# 43      Black  Marvel Comics         -  ...         False            False
# 260       Red  Marvel Comics         -  ...         False            False
# 35          -  Marvel Comics         -  ...         False             True
#
# ...

# %%
good_max_power_full=good[good['Power']==100]

# %%
good_max_power_full.shape
# Out:
# (19, 186)

# %%
good_max_power_full
# Out:
#      Unnamed: 0   ID            Name Alignment_x  Gender EyeColor  \
# 34           34   78   Beta Ray Bill        good    Male        -
# 35           35   79        Beyonder        good    Male        -
# 43           43   95      Black Bolt        good    Male     blue
# 73           73  144           Cable        good    Male     blue
# 115         115  225  Doctor Strange        good    Male     grey
# 177         177  338          Iceman        good    Male    brown
# 181         181  345        Iron Man        good    Male     blue
# 184         184  355       Jean Grey        good  Female    green
# 220         220  433     Marvel Girl        good  Female    green
# 251         251  496            Nova        good    Male    brown
# 252         252  497         Nova II        good  Female    white
# 260         260  518         Phoenix        good  Female    green
# 291         291  586     Shadow King        good       -      red
# ...

# %%
good_max_power_full=good.sort_values(by=['Total'],ascending=False)

# %%
good_max_power_full.head()
# Out:
#      Unnamed: 0   ID       Name Alignment_x  Gender EyeColor       Race  \
# 321         321  633   Stardust        good    Male        -          -
# 330         330  661       Thor        good    Male     blue  Asgardian
# 251         251  496       Nova        good    Male    brown      Human
# 184         184  355  Jean Grey        good  Female    green     Mutant
# 260         260  518    Phoenix        good  Female    green     Mutant
#
#     HairColor      Publisher SkinColor  ...  Web Creation  Reality Warping  \
# 321         -  Marvel Comics         -  ...         False            False
# 330     Blond  Marvel Comics         -  ...         False            False
# 251     Brown  Marvel Comics         -  ...         False            False
# 184       Red  Marvel Comics         -  ...         False            False
# 260       Red  Marvel Comics         -  ...         False            False
#
#      Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# ...

# %%
plt.figure(figsize=(15,7))
plt.bar(list(good_max_power_full['Name'])[0:7],list(good_max_power_full['Total'])[0:7],color='g')
# Out:
# <BarContainer object of 7 artists>

# %%
bad = marvel[marvel['Alignment_x']=='bad']
bad.head()
# Out:
#    Unnamed: 0  ID           Name Alignment_x Gender EyeColor  \
# 1           1   3    Abomination         bad   Male    green
# 2           2   4        Abraxas         bad   Male     blue
# 3           3   5  Absorbing Man         bad   Male     blue
# 7           7  11     Air-Walker         bad   Male     blue
# 8           8  12           Ajax         bad   Male    brown
#
#                 Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 1  Human / Radiation   No Hair  Marvel Comics         -  ...         False
# 2      Cosmic Entity     Black  Marvel Comics         -  ...         False
# 3              Human   No Hair  Marvel Comics         -  ...         False
# 7                  -     White  Marvel Comics         -  ...         False
# 8             Cyborg     Black  Marvel Comics         -  ...         False
#
#    Reality Warping  Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# ...

# %%
bad.sort_values(by=['Speed'],ascending=False).head()
# Out:
#      Unnamed: 0   ID           Name Alignment_x Gender EyeColor  \
# 7             7   11     Air-Walker         bad   Male     blue
# 129         129  251  Fallen One II         bad   Male    black
# 120         120  234            Ego         bad      -        -
# 118         118  231       Dormammu         bad   Male   yellow
# 2             2    4        Abraxas         bad   Male     blue
#
#               Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 7                -     White  Marvel Comics         -  ...         False
# 129              -      Blue  Marvel Comics         -  ...         False
# 120              -         -  Marvel Comics         -  ...         False
# 118              -   No Hair  Marvel Comics         -  ...         False
# 2    Cosmic Entity     Black  Marvel Comics         -  ...         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 7              False       False             False        False
# ...

# %%
bad.sort_values(by=['Intelligence_x'],ascending=False).head()
# Out:
#      Unnamed: 0   ID         Name Alignment_x Gender EyeColor    Race  \
# 218         218  430     Mandarin         bad   Male     blue   Human
# 17           17   34   Apocalypse         bad   Male      red  Mutant
# 194         194  378         Kang         bad   Male    brown       -
# 112         112  221  Doctor Doom         bad   Male    brown   Human
# 339         339  670     Tinkerer         bad   Male    brown       -
#
#     HairColor      Publisher SkinColor  ...  Web Creation  Reality Warping  \
# 218     White  Marvel Comics         -  ...         False            False
# 17      Black  Marvel Comics      grey  ...         False            False
# 194     Brown  Marvel Comics         -  ...         False            False
# 112     Brown  Marvel Comics         -  ...         False            False
# 339     White  Marvel Comics         -  ...         False            False
#
#      Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# ...

# %%
bad.sort_values(by=['Total'],ascending=False).head()
# Out:
#      Unnamed: 0   ID           Name Alignment_x Gender EyeColor  \
# 118         118  231       Dormammu         bad   Male   yellow
# 215         215  425          Magus         bad   Male    black
# 2             2    4        Abraxas         bad   Male     blue
# 129         129  251  Fallen One II         bad   Male    black
# 256         256  504      Onslaught         bad   Male      red
#
#               Race HairColor      Publisher SkinColor  ...  Web Creation  \
# 118              -   No Hair  Marvel Comics         -  ...         False
# 215              -         -  Marvel Comics         -  ...         False
# 2    Cosmic Entity     Black  Marvel Comics         -  ...         False
# 129              -      Blue  Marvel Comics         -  ...         False
# 256         Mutant   No Hair  Marvel Comics         -  ...         False
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 118            False       False             False        False
# ...

# %%
plt.figure(figsize=(15,7))
plt.hist(good['Speed'])
plt.title('Speed Distribution')
plt.xlabel('Speed')
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.hist(bad['Combat'])
plt.title('Combat Distribution')
plt.xlabel('combat')
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.hist(bad['Combat'])
plt.title('cpmbat Distribution')
plt.xlabel('combat')
plt.show()
