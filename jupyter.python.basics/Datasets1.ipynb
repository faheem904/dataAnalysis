# %%
import pandas as pd

# %%
iris = pd.read_csv('Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.iloc[0:4,0:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm
# 0   1            5.1           3.5
# 1   2            4.9           3.0
# 2   3            4.7           3.2
# 3   4            4.6           3.1

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.iloc[5:10,2:4]
# Out:
#    SepalWidthCm  PetalLengthCm
# 5           3.9            1.7
# 6           3.4            1.4
# 7           3.4            1.5
# 8           2.9            1.4
# 9           3.1            1.5

# %%
iris.iloc[5:11,2:]
# Out:
#     SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5            3.9            1.7           0.4  Iris-setosa
# 6            3.4            1.4           0.3  Iris-setosa
# 7            3.4            1.5           0.2  Iris-setosa
# 8            2.9            1.4           0.2  Iris-setosa
# 9            3.1            1.5           0.1  Iris-setosa
# 10           3.7            1.5           0.2  Iris-setosa

# %%
iris.loc[0:3,("PetalLengthCm", "Species")]
# Out:
#    PetalLengthCm      Species
# 0            1.4  Iris-setosa
# 1            1.4  Iris-setosa
# 2            1.3  Iris-setosa
# 3            1.5  Iris-setosa

# %%
only_numbers = iris.drop('Species', axis=1)

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
only_numbers.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2
# 2   3            4.7           3.2            1.3           0.2
# 3   4            4.6           3.1            1.5           0.2
# 4   5            5.0           3.6            1.4           0.2

# %%
iris.drop([1, 2, 3, 4],axis=0)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# ..              ...
# ...

# %%
i1=iris.drop([5, 6, 7],axis=0)

# %%
i1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.min()
# Out:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
iris.max()
# Out:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %%
only_numbers.mean()
# Out:
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %%
only_numbers.median()
# Out:
# Id               75.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
def half(s):
    return s*0.5

# %%
iris[['SepalLengthCm', 'PetalLengthCm']].apply(half)
# Out:
#      SepalLengthCm  PetalLengthCm
# 0             2.55           0.70
# 1             2.45           0.70
# 2             2.35           0.65
# 3             2.30           0.75
# 4             2.50           0.70
# ..             ...            ...
# 145           3.35           2.60
# 146           3.15           2.50
# 147           3.25           2.60
# 148           3.10           2.70
# 149           2.95           2.55
#
# [150 rows x 2 columns]

# %%
def double(s):
    return s*2

# %%
iris[['SepalWidthCm ','PetalWidthCm']].apply(double)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 iris[['SepalWidthCm ','PetalWidthCm']].apply(double)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
# ...

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
def doublemake(s):
    return s*2

# %%
iris[["SepalLengthCm", "PetalWidthCm"]].apply(doublemake)
# Out:
#      SepalLengthCm  PetalWidthCm
# 0             10.2           0.4
# 1              9.8           0.4
# 2              9.4           0.4
# 3              9.2           0.4
# 4             10.0           0.4
# ..             ...           ...
# 145           13.4           4.6
# 146           12.6           3.8
# 147           13.0           4.0
# 148           12.4           4.6
# 149           11.8           3.6
#
# [150 rows x 2 columns]

# %%
iris["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
iris.sort_values(by="PetalWidthCm")
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 32    33            5.2           4.1            1.5           0.1
# 13    14            4.3           3.0            1.1           0.1
# 37    38            4.9           3.1            1.5           0.1
# 9     10            4.9           3.1            1.5           0.1
# 12    13            4.8           3.0            1.4           0.1
# ..   ...            ...           ...            ...           ...
# 140  141            6.7           3.1            5.6           2.4
# 114  115            5.8           2.8            5.1           2.4
# 100  101            6.3           3.3            6.0           2.5
# 144  145            6.7           3.3            5.7           2.5
# 109  110            7.2           3.6            6.1           2.5
#
#             Species
# 32      Iris-setosa
# 13      Iris-setosa
# 37      Iris-setosa
# 9       Iris-setosa
# 12      Iris-setosa
# ..              ...
# ...
